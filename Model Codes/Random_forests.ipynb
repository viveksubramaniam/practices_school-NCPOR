# %%
import numpy as np 
import pandas as pd 
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('.\Dataset\data_trial.csv')

# %%
df = pd.DataFrame(data)

# %%
df.set_index('date', inplace = True)

# %%
df
# Out:
#                      tempr      ap     ws     rh  blizzard
# date
# 2016-01-01 00:00:00   1.16  980.83   8.27  67.60         0
# 2016-01-01 01:00:00   1.35  980.95  10.91  65.30         0
# 2016-01-01 02:00:00   1.53  981.07   8.59  64.70         0
# 2016-01-01 03:00:00   1.43  981.37   8.18  66.10         0
# 2016-01-01 04:00:00   1.24  981.66   9.19  73.86         0
# ...                    ...     ...    ...    ...       ...
# 2021-02-04 19:00:00  -4.58  975.76   3.17  60.35         0
# 2021-02-04 20:00:00  -3.88  975.98   5.95  51.05         0
# 2021-02-04 21:00:00  -4.50  976.21   7.17  49.89         0
# 2021-02-04 22:00:00  -4.98  976.44   7.22  50.56         0
# 2021-02-04 23:00:00  -4.93  976.67   7.07  51.44         0
#
# [44688 rows x 5 columns]

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
sup_data = series_to_supervised(data)

# %%
sup_data
# Out:
#                      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  \
# date
# 2016-01-01 01:00:00       1.16     980.83       8.27      67.60        0.0
# 2016-01-01 02:00:00       1.35     980.95      10.91      65.30        0.0
# 2016-01-01 03:00:00       1.53     981.07       8.59      64.70        0.0
# 2016-01-01 04:00:00       1.43     981.37       8.18      66.10        0.0
# 2016-01-01 05:00:00       1.24     981.66       9.19      73.86        0.0
# ...                        ...        ...        ...        ...        ...
# 2021-02-04 19:00:00      -4.33     975.59       1.94      65.52        0.0
# 2021-02-04 20:00:00      -4.58     975.76       3.17      60.35        0.0
# 2021-02-04 21:00:00      -3.88     975.98       5.95      51.05        0.0
# 2021-02-04 22:00:00      -4.50     976.21       7.17      49.89        0.0
# 2021-02-04 23:00:00      -4.98     976.44       7.22      50.56        0.0
#
#                      var1(t)  var2(t)  var3(t)  var4(t)  var5(t)
# date
# 2016-01-01 01:00:00     1.35   980.95    10.91    65.30        0
# 2016-01-01 02:00:00     1.53   981.07     8.59    64.70        0
# 2016-01-01 03:00:00     1.43   981.37     8.18    66.10        0
# 2016-01-01 04:00:00     1.24   981.66     9.19    73.86        0
# 2016-01-01 05:00:00     1.57   981.96    10.45    68.28        0
# ...                      ...      ...      ...      ...      ...
# 2021-02-04 19:00:00    -4.58   975.76     3.17    60.35        0
# 2021-02-04 20:00:00    -3.88   975.98     5.95    51.05        0
# 2021-02-04 21:00:00    -4.50   976.21     7.17    49.89        0
# 2021-02-04 22:00:00    -4.98   976.44     7.22    50.56        0
# 2021-02-04 23:00:00    -4.93   976.67     7.07    51.44        0
#
# [44687 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 1000)

# %%
from sklearn.model_selection import train_test_split

tX_train, tX_test, ty_train, ty_test = train_test_split(sup_data['var1(t-1)'], sup_data['var1(t)'], test_size = 0.3, shuffle = False)

# %%
X = tX_train.to_numpy().reshape(-1,1)
y = ty_train.to_numpy().reshape(-1,1)

model.fit(X, y)

y_pred = model.predict(tX_test.to_numpy().reshape(-1,1))
# Out:
# <ipython-input-32-7cb969c421ed>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X, y)

# %%
plt.plot(ty_test.to_numpy().reshape(-1,1), label = 'Expected')
plt.plot(y_pred, label = 'Predcited')
plt.legend()
plt.show()

# %% [markdown]
# # WindSpeed predictions

# %%
wX_train, wX_test, wy_train, wy_test = train_test_split(sup_data['var3(t-1)'], sup_data['var3(t)'], test_size = 0.3, shuffle = False)

# %%
wX = wX_train.to_numpy().reshape(-1,1)
wy = wy_train.to_numpy().reshape(-1,1)

model.fit(wX, wy)

wy_pred = model.predict(wX_test.to_numpy().reshape(-1,1))
# Out:
# <ipython-input-34-28d98efa93f3>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(wX, wy)

# %%
plt.plot(wy_test.to_numpy().reshape(-1,1), label = 'Expected')
plt.plot(wy_pred, label = 'Predcited')
plt.legend()
plt.show()

# %% [markdown]
# ## Performance Metrics
#
# To calculate the performance of any regressor model, we need to use MAPE (Mean Average Percentage Error).
#
# First take the difference and then divide each by the test labels and multiply by 100. Subtract 100 from the mean of the mape and thats the accuracy.

# %%
w_errors = abs(wy_pred - wy_test)
w_mae = round(np.mean(w_errors), 2)
w_mape = 100 * ( w_errors / wy_test)

accuracy = 100 - np.mean(w_mape)

print(accuracy)
# Out:
# 73.85406554714686

# %% [markdown]
# # Atmoshperic Pressure Predictions

# %%
aX_train, aX_test, ay_train, ay_test = train_test_split(sup_data['var2(t-1)'], sup_data['var2(t)'], test_size = 0.3, shuffle = False)

# %%
aX = aX_train.to_numpy().reshape(-1,1)
ay = ay_train.to_numpy().reshape(-1,1)

model.fit(aX, ay)

ay_pred = model.predict(aX_test.to_numpy().reshape(-1,1))
# Out:
# <ipython-input-36-aa24665520f5>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(aX, ay)

# %%
plt.plot(ay_test.to_numpy().reshape(-1,1), label = 'Expected')
plt.plot(ay_pred, label = 'Predcited')
plt.legend()
plt.show()

# %%
a_errors = abs(ay_pred - ay_test)

a_mae = round(np.mean(a_errors), 2)
a_mape = 100 * ( a_errors / ay_test)

accuracy = 100 - np.mean(a_mape)
print(accuracy)
# Out:
# 99.93141444919607

# %% [markdown]
# # RH Predictions

# %%
rX_train, rX_test, ry_train, ry_test = train_test_split(sup_data['var4(t-1)'], sup_data['var4(t)'], test_size = 0.3, shuffle = False)

# %%
rX = rX_train.to_numpy().reshape(-1,1)
ry = ry_train.to_numpy().reshape(-1,1)

model.fit(rX, ry)

ry_pred = model.predict(rX_test.to_numpy().reshape(-1,1))
# Out:
# <ipython-input-38-2baaa25d0c8f>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(rX, ry)

# %%
plt.plot(ry_test.to_numpy().reshape(-1,1), label = 'Expected')
plt.plot(ry_pred, label = 'Predcited')
plt.legend()
plt.show()

# %%
r_errors = abs(ry_pred - ry_test)

r_mae = round(np.mean(r_errors), 2)
r_mape = 100 * ( r_errors / ry_test)

accuracy = 100 - np.mean(r_mape)
print(accuracy)
# Out:
# 94.99293403402238
